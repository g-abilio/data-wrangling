# %% [markdown]
# # Opening CSV

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("ds-salaries.csv")

# %%
df
# Out:
#     work_year experience_level employment_type                  job_title  \
# 0       2021e               EN              FT    Data Science Consultant
# 1        2020               SE              FT             Data Scientist
# 2       2021e               EX              FT       Head of Data Science
# 3       2021e               EX              FT               Head of Data
# 4       2021e               EN              FT  Machine Learning Engineer
# ..        ...              ...             ...                        ...
# 240      2020               SE              FT             Data Scientist
# 241     2021e               MI              FT   Principal Data Scientist
# 242      2020               EN              FT             Data Scientist
# 243      2020               EN              CT      Business Data Analyst
# 244     2021e               SE              FT       Data Science Manager
#
#       salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           245 non-null    object
#  1   experience_level    245 non-null    object
#  2   employment_type     245 non-null    object
#  3   job_title           245 non-null    object
#  4   salary              245 non-null    int64
#  5   salary_currency     245 non-null    object
#  6   salary_in_usd       245 non-null    int64
#  7   employee_residence  245 non-null    object
#  8   remote_ratio        245 non-null    int64
#  9   company_location    245 non-null    object
#  10  company_size        245 non-null    object
# dtypes: int64(3), object(8)
# memory usage: 21.2+ KB

# %%
df.describe()
# Out:
#              salary  salary_in_usd  remote_ratio
# count  2.450000e+02     245.000000    245.000000
# mean   5.025418e+05   99868.012245     69.183673
# std    2.276230e+06   83983.326949     37.593421
# min    4.000000e+03    2876.000000      0.000000
# 25%    6.000000e+04   45896.000000     50.000000
# 50%    1.030000e+05   81000.000000    100.000000
# 75%    1.740000e+05  130000.000000    100.000000
# max    3.040000e+07  600000.000000    100.000000

# %% [markdown]
# ## Plotting

# %% [markdown]
# We are going to skip the scattering and the color map, because it doesn't make sense using these tools here, as the results of the plottings are very bad.

# %%
non_numerical_values = set(df.columns) - {"salary", "salary_in_usd", "remote_ratio"}
non_numerical_values
# Out:
# {'company_location',
#  'company_size',
#  'employee_residence',
#  'employment_type',
#  'experience_level',
#  'job_title',
#  'salary_currency',
#  'work_year'}

# %%
numerical_values = set(df.columns) - non_numerical_values
numerical_values
# Out:
# {'remote_ratio', 'salary', 'salary_in_usd'}

# %% [markdown]
# ### Line

# %%
for i in numerical_values:
        df.plot(y = i)

# %% [markdown]
# ### Area Plotting

# %%
for i in numerical_values:
    df.plot(y = i, kind = "area")

# %% [markdown]
# ### Bar charts

# %% [markdown]
# Not displays a great result in respect of the distribution of the numerical values on the dataframe according to the index as the number f indexes is to high.

# %%
for i in numerical_values:
    df.plot(y = i, kind = "bar")

# %% [markdown]
# ### Histograms

# %%
df["salary"].plot(kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["salary_in_usd"].plot(kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["remote_ratio"].plot(kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### Density functions

# %%
df["salary"].plot(kind = "kde")
# Out:
# <Axes: ylabel='Density'>

# %%
df["salary_in_usd"].plot(kind = "kde")
# Out:
# <Axes: ylabel='Density'>

# %%
df["remote_ratio"].plot(kind = "kde")
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ### Box plot

# %% [markdown]
# Here, the remote_ratio plot is not very good. However the salary and salary_in_usd represents nice results, in major the salary_in_usd. It's interesting to see that we have a lot of abnormal points above the upper arrow, and that the very low salaries are expected, according to the lower arrow.

# %%
df["salary"].plot(kind = "box")
# Out:
# <Axes: >

# %%
df["salary_in_usd"].plot(kind = "box")
# Out:
# <Axes: >

# %%
df["remote_ratio"].plot(kind = "box")
# Out:
# <Axes: >

# %%
df[["salary", "salary_in_usd"]].corr()
# Out:
#                  salary  salary_in_usd
# salary         1.000000      -0.087365
# salary_in_usd -0.087365       1.000000

# %% [markdown]
# ### Pie chart

# %%
non_numerical_values
# Out:
# {'company_location',
#  'company_size',
#  'employee_residence',
#  'employment_type',
#  'experience_level',
#  'job_title',
#  'salary_currency',
#  'work_year'}

# %%
df["company_location"].value_counts().plot(kind = "pie")
# Out:
# <Axes: ylabel='count'>

# %%
df["company_size"].value_counts().plot(kind = "pie")
# Out:
# <Axes: ylabel='count'>

# %%
df["employee_residence"].value_counts().plot(kind = "pie")
# Out:
# <Axes: ylabel='count'>

# %%
df["employment_type"].value_counts().plot(kind = "pie")
# Out:
# <Axes: ylabel='count'>

# %%
df["experience_level"].value_counts().plot(kind = "pie")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Too many jobs :0

# %%
df["job_title"].value_counts().plot(kind = "pie")
# Out:
# <Axes: ylabel='count'>

# %%
df["salary_currency"].value_counts().plot(kind = "pie")
# Out:
# <Axes: ylabel='count'>

# %%
df["work_year"].value_counts().plot(kind = "pie")
# Out:
# <Axes: ylabel='count'>
