# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Spotify_Youtube.csv", skiprows = 2, index_col = 0)
df
# Out:
#                                                      Track  \
# Artist
# Gorillaz                                    Feel Good Inc.
# Gorillaz                                   Rhinestone Eyes
# Gorillaz     New Gold (feat. Tame Impala and Bootie Brown)
# Gorillaz                                On Melancholy Hill
# Gorillaz                                    Clint Eastwood
# ...                                                    ...
# SICK LEGEND                           JUST DANCE HARDSTYLE
# SICK LEGEND                 SET FIRE TO THE RAIN HARDSTYLE
# SICK LEGEND                      OUTSIDE HARDSTYLE SPED UP
# SICK LEGEND                            ONLY GIRL HARDSTYLE
# SICK LEGEND                             MISS YOU HARDSTYLE
#
#                                                      Album Album_type  \
# Artist
# Gorillaz                                        Demon Days      album
# Gorillaz                                     Plastic Beach      album
# ...

# %%
df.head()
# Out:
#                                                   Track  \
# Artist
# Gorillaz                                 Feel Good Inc.
# Gorillaz                                Rhinestone Eyes
# Gorillaz  New Gold (feat. Tame Impala and Bootie Brown)
# Gorillaz                             On Melancholy Hill
# Gorillaz                                 Clint Eastwood
#
#                                                   Album Album_type  \
# Artist
# Gorillaz                                     Demon Days      album
# Gorillaz                                  Plastic Beach      album
# Gorillaz  New Gold (feat. Tame Impala and Bootie Brown)     single
# Gorillaz                                  Plastic Beach      album
# Gorillaz                                       Gorillaz      album
#
#                 Views      Likes  Comments Licensed official_video  \
# Artist
# Gorillaz  693555221.0  6220896.0  169907.0     True           True
# ...

# %%
df.tail()
# Out:
#                                       Track                           Album  \
# Artist
# SICK LEGEND            JUST DANCE HARDSTYLE            JUST DANCE HARDSTYLE
# SICK LEGEND  SET FIRE TO THE RAIN HARDSTYLE  SET FIRE TO THE RAIN HARDSTYLE
# SICK LEGEND       OUTSIDE HARDSTYLE SPED UP       OUTSIDE HARDSTYLE SPED UP
# SICK LEGEND             ONLY GIRL HARDSTYLE             ONLY GIRL HARDSTYLE
# SICK LEGEND              MISS YOU HARDSTYLE              MISS YOU HARDSTYLE
#
#             Album_type     Views   Likes  Comments Licensed official_video  \
# Artist
# SICK LEGEND     single   71678.0  1113.0       0.0     True           True
# SICK LEGEND     single  164741.0  2019.0       0.0     True           True
# SICK LEGEND     single   35646.0   329.0       0.0     True           True
# SICK LEGEND     single    6533.0    88.0       0.0     True           True
# SICK LEGEND     single  158697.0  2484.0       0.0     True           True
#
#                  Stream
# Artist
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20718 entries, Gorillaz to SICK LEGEND
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Track           20718 non-null  object
#  1   Album           20718 non-null  object
#  2   Album_type      20718 non-null  object
#  3   Views           20248 non-null  float64
#  4   Likes           20177 non-null  float64
#  5   Comments        20149 non-null  float64
#  6   Licensed        20248 non-null  object
#  7   official_video  20248 non-null  object
#  8   Stream          20142 non-null  float64
# dtypes: float64(4), object(5)
# memory usage: 1.6+ MB

# %%
df.shape
# Out:
# (20718, 9)

# %%
needed_columns = ["Album", "Album_type", "Likes"]
df_new = df.loc[:, needed_columns]
df_new
# Out:
#                                                      Album Album_type  \
# Artist
# Gorillaz                                        Demon Days      album
# Gorillaz                                     Plastic Beach      album
# Gorillaz     New Gold (feat. Tame Impala and Bootie Brown)     single
# Gorillaz                                     Plastic Beach      album
# Gorillaz                                          Gorillaz      album
# ...                                                    ...        ...
# SICK LEGEND                           JUST DANCE HARDSTYLE     single
# SICK LEGEND                 SET FIRE TO THE RAIN HARDSTYLE     single
# SICK LEGEND                      OUTSIDE HARDSTYLE SPED UP     single
# SICK LEGEND                            ONLY GIRL HARDSTYLE     single
# SICK LEGEND                             MISS YOU HARDSTYLE     single
#
#                  Likes
# Artist
# Gorillaz     6220896.0
# Gorillaz     1079128.0
# Gorillaz      282142.0
# ...

# %%
df = pd.read_csv("Spotify_Youtube.csv", skiprows = 2)
df
# Out:
#             Artist                                          Track  \
# 0         Gorillaz                                 Feel Good Inc.
# 1         Gorillaz                                Rhinestone Eyes
# 2         Gorillaz  New Gold (feat. Tame Impala and Bootie Brown)
# 3         Gorillaz                             On Melancholy Hill
# 4         Gorillaz                                 Clint Eastwood
# ...            ...                                            ...
# 20713  SICK LEGEND                           JUST DANCE HARDSTYLE
# 20714  SICK LEGEND                 SET FIRE TO THE RAIN HARDSTYLE
# 20715  SICK LEGEND                      OUTSIDE HARDSTYLE SPED UP
# 20716  SICK LEGEND                            ONLY GIRL HARDSTYLE
# 20717  SICK LEGEND                             MISS YOU HARDSTYLE
#
#                                                Album Album_type        Views  \
# 0                                         Demon Days      album  693555221.0
# ...

# %%
df_alsubset = df.loc[[np.random.randint(0, len(df)) for x in range(5)], ["Artist", "Album", "Licensed"]]
df_alsubset
# Out:
#                  Artist                                              Album  \
# 2101      Ozzy Osbourne  Blizzard Of Ozz (40th Anniversary Expanded Edi...
# 17736       Men I Trust                                         Oncle Jazz
# 16953       Jess Glynne                                 I Cry When I Laugh
# 10978       Benny Dayal                                            Befikre
# 3944   Sukhwinder Singh                     Rab Ne Bana Di Jodi (Original)
#
#       Licensed
# 2101     False
# 17736     True
# 16953     True
# 10978     True
# 3944      True

# %%
[i for i in range(len(df["Artist"])) if df["Artist"].iloc[i] == "Pink Floyd"]
# Out:
# [499, 500, 501, 502, 503, 504, 505, 506, 507, 508]

# %%
df_pf = df.iloc[499:509]
df_pf
# Out:
#          Artist                             Track                      Album  \
# 499  Pink Floyd  Another Brick in the Wall, Pt. 2                   The Wall
# 500  Pink Floyd                Wish You Were Here         Wish You Were Here
# 501  Pink Floyd          The Great Gig in the Sky  The Dark Side of the Moon
# 502  Pink Floyd                  Comfortably Numb                   The Wall
# 503  Pink Floyd                             Money  The Dark Side of the Moon
# 504  Pink Floyd              Breathe (In the Air)  The Dark Side of the Moon
# 505  Pink Floyd                              Time  The Dark Side of the Moon
# 506  Pink Floyd                           Hey You                   The Wall
# 507  Pink Floyd                      Brain Damage  The Dark Side of the Moon
# 508  Pink Floyd                       Us and Them  The Dark Side of the Moon
#
#     Album_type       Views     Likes  Comments Licensed official_video  \
# ...

# %%
df_pf.describe()
# Out:
#               Views          Likes     Comments       Stream
# count  1.000000e+01       9.000000    10.000000          1.0
# mean   8.542964e+06   86566.777778  1984.000000  557368632.0
# std    1.463476e+07  138700.073221  2659.827981          NaN
# min    3.355200e+04    1643.000000    53.000000  557368632.0
# 25%    1.925205e+05    5849.000000   205.250000  557368632.0
# 50%    4.805145e+05    8034.000000   342.000000  557368632.0
# 75%    7.151902e+06   83454.000000  3510.750000  557368632.0
# max    4.225247e+07  405995.000000  7172.000000  557368632.0

# %%
df_pf.isnull().sum()
# Out:
# Artist            0
# Track             0
# Album             0
# Album_type        0
# Views             0
# Likes             1
# Comments          0
# Licensed          0
# official_video    0
# Stream            9
# dtype: int64

# %%
df["Artist"].unique()
# Out:
# array(['Gorillaz', 'Red Hot Chili Peppers', '50 Cent', ..., 'LE SSERAFIM',
#        'ThxSoMch', 'SICK LEGEND'], dtype=object)

# %%
df["Artist"].nunique()
# Out:
# 2079

# %%
df
# Out:
#             Artist                                          Track  \
# 0         Gorillaz                                 Feel Good Inc.
# 1         Gorillaz                                Rhinestone Eyes
# 2         Gorillaz  New Gold (feat. Tame Impala and Bootie Brown)
# 3         Gorillaz                             On Melancholy Hill
# 4         Gorillaz                                 Clint Eastwood
# ...            ...                                            ...
# 20713  SICK LEGEND                           JUST DANCE HARDSTYLE
# 20714  SICK LEGEND                 SET FIRE TO THE RAIN HARDSTYLE
# 20715  SICK LEGEND                      OUTSIDE HARDSTYLE SPED UP
# 20716  SICK LEGEND                            ONLY GIRL HARDSTYLE
# 20717  SICK LEGEND                             MISS YOU HARDSTYLE
#
#                                                Album Album_type        Views  \
# 0                                         Demon Days      album  693555221.0
# ...

# %%
df["Views"] > 500000000
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 20713    False
# 20714    False
# 20715    False
# 20716    False
# 20717    False
# Name: Views, Length: 20718, dtype: bool

# %%
df_popular = df[df["Views"] > 500000000]
df_popular
# Out:
#                       Artist                Track  \
# 0                   Gorillaz       Feel Good Inc.
# 4                   Gorillaz       Clint Eastwood
# 10     Red Hot Chili Peppers      Californication
# 14     Red Hot Chili Peppers            Otherside
# 20                   50 Cent           In Da Club
# ...                      ...                  ...
# 20307              CoComelon    Itsy Bitsy Spider
# 20308              CoComelon           Baby Shark
# 20309              CoComelon        Old MacDonald
# 20310              CoComelon        Finger Family
# 20569             Silk Sonic  Leave The Door Open
#
#                                   Album Album_type         Views       Likes  \
# 0                            Demon Days      album  6.935552e+08   6220896.0
# 4                              Gorillaz      album  6.184810e+08   6197318.0
# 10     Californication (Deluxe Edition)      album  1.018811e+09   4394471.0
# ...

# %%
df_popular_liked = df[(df["Views"] > 1000000000) & (df["Likes"] > 50000000)]
df_popular_liked
# Out:
#             Artist      Track Album Album_type         Views       Likes  \
# 365   Daddy Yankee  Despacito  VIDA      album  8.079647e+09  50788626.0
# 1147    Luis Fonsi  Despacito  VIDA      album  8.079649e+09  50788652.0
#
#        Comments Licensed official_video        Stream
# 365   4252791.0     True           True  1.506598e+09
# 1147  4252791.0     True           True  1.506598e+09

# %%
df_popular2 = df[df["Views"] > 5000000000]
df_popular2
# Out:
#              Artist                               Track  \
# 365    Daddy Yankee                           Despacito
# 1147     Luis Fonsi                           Despacito
# 12452    Ed Sheeran                        Shape of You
# 12469   Wiz Khalifa  See You Again (feat. Charlie Puth)
# 14580  Charlie Puth  See You Again (feat. Charlie Puth)
#
#                                     Album Album_type         Views  \
# 365                                  VIDA      album  8.079647e+09
# 1147                                 VIDA      album  8.079649e+09
# 12452                          ÷ (Deluxe)      album  5.908398e+09
# 12469  See You Again (feat. Charlie Puth)     single  5.773797e+09
# 14580  See You Again (feat. Charlie Puth)     single  5.773798e+09
#
#             Likes   Comments Licensed official_video        Stream
# 365    50788626.0  4252791.0     True           True  1.506598e+09
# 1147   50788652.0  4252791.0     True           True  1.506598e+09
# ...

# %%
df_art = df.groupby("Artist")

# %%
df_art

# %%
df_art.sum()
# Out:
#                                                             Track  \
# Artist
# $NOT            Tell EmGOSHADemon (featuring $NOT)Moon & Stars...
# $uicideboy$     ...And to Those I Love, Thanks for Sticking Ar...
# (G)I-DLE        NxdeTOMBOYMY BAGPOP/STARSMOREOh my godTHE BADD...
# *NSYNC          Merry Christmas, Happy HolidaysBye Bye ByeIt's...
# 070 Shake       Escapism.Escapism. - Sped UpGuilty ConscienceH...
# ...                                                           ...
# will.i.am       Scream & ShoutI Like To Move It#thatPOWERHot W...
# Ángela Aguilar  Qué AgoníaDime Cómo QuieresTu Sangre en Mi Cue...
# Ñejo            ¿Cual Es Tu Plan?FERXXO X ÑEJOY Si La VesMonum...
# Ñengo Flow      Gato de NocheLa Llevo Al Cielo (Ft. Ñengo Flow...
# Øneheart        snowfallsnowfall (Sped Up)snowfall (Slowed + R...
#
#                                                             Album  \
# Artist
# $NOT            Tell Em- TRAGEDY +Fast & Furious: Drift Tape (...
# ...

# %%
df_art.sum().sort_values(by = ["Likes"], ascending = False)
# Out:
#                                                                     Track  \
# Artist
# BTS                     Dreamers [Music from the FIFA World Cup Qatar ...
# BLACKPINK               Shut DownPink VenomTypa GirlAs If It's Your La...
# Charlie Puth            Left and Right (Feat. Jung Kook of BTS)Attenti...
# Ed Sheeran              PerfectBad HabitsShiversShape of YouPhotograph...
# Justin Bieber           STAY (with Justin Bieber)GhostPeaches (feat. D...
# ...                                                                   ...
# Matheus & Kauan         Pactos - Ao VivoEsse B.O é Meu - Ao VivoBasiqu...
# Jorge & Mateus          Pactos - Ao Vivo5 Regras - Ao VivoBeijo de Gli...
# Ben&Ben                 Paninindigan KitaKathang IsipSa Susunod na Hab...
# KC & The Sunshine Band  Give It UpPlease Don't Go - Single VersionThat...
# Milionário & José Rico  Vontade Dividida - Ao VivoEstrada da vidaA Car...
#
# ...

# %%
df_art.describe()
# Out:
#                Views                                                      \
#                count         mean           std        min           25%
# Artist
# $NOT            10.0   11078490.3  1.187537e+07    76559.0  2.997504e+06
# $uicideboy$     10.0   33413510.8  5.705082e+07    39287.0  1.319265e+06
# (G)I-DLE        10.0  175495394.1  1.441685e+08    13310.0  1.136119e+08
# *NSYNC          10.0  102783286.2  1.093834e+08    76180.0  2.408796e+07
# 070 Shake       10.0    9609935.9  1.105354e+07   756640.0  1.424996e+06
# ...              ...          ...           ...        ...           ...
# will.i.am       10.0  283132016.6  3.878980e+08   519453.0  1.356606e+07
# Ángela Aguilar  10.0  138529529.1  1.846500e+08   868506.0  2.823592e+07
# Ñejo            10.0   62668082.4  5.223733e+07  4495434.0  3.295199e+07
# Ñengo Flow      10.0   81272631.5  1.159511e+08     5652.0  3.033442e+06
# Øneheart        10.0    3462331.0  6.291829e+06    13420.0  1.598062e+05
#
# ...

# %%
df_art.describe().loc["The Beatles"]
# Out:
# Views     count    1.000000e+01
#           mean     6.542037e+07
#           std      3.663983e+07
#           min      2.879945e+07
#           25%      3.610388e+07
#           50%      5.505856e+07
#           75%      8.844308e+07
#           max      1.319251e+08
# Likes     count    1.000000e+01
#           mean     5.792374e+05
#           std      2.939543e+05
#           min      2.759210e+05
#           25%      4.028798e+05
#           50%      4.692020e+05
#           75%      6.290870e+05
#           max      1.126554e+06
# Comments  count    1.000000e+01
#           mean     1.122000e+04
#           std      1.049493e+04
#           min      3.211000e+03
#           25%      4.362250e+03
#           50%      6.253500e+03
#           75%      1.374075e+04
#           max      3.291000e+04
# Stream    count    1.000000e+01
#           mean     4.509275e+08
#           std      2.073959e+08
#           min      2.333821e+08
#           25%      3.287758e+08
# ...

# %%
df_art.describe().loc[["The Beatles", "Pink Floyd", "Caetano Veloso"], ["Views", "Likes"]]
# Out:
#                Views                                                    \
#                count        mean           std         min         25%
# Artist
# The Beatles     10.0  65420371.7  3.663983e+07  28799448.0  36103880.5
# Pink Floyd      10.0   8542964.3  1.463476e+07     33552.0    192520.5
# Caetano Veloso  10.0   4277396.2  7.904430e+06     23864.0     94363.0
#
#                                                     Likes                 \
#                        50%         75%          max count           mean
# Artist
# The Beatles     55058563.5  88443080.0  131925109.0  10.0  579237.400000
# Pink Floyd        480514.5   7151902.5   42252469.0   9.0   86566.777778
# Caetano Veloso    794642.5   1672358.0   22580609.0  10.0   28236.200000
#
#                                                                          \
#                           std       min        25%       50%        75%
# Artist
# ...

# %%
df_art_album = df.groupby(["Artist", "Album"])
df_art_album

# %%
df_art_album.describe()
# Out:
#                                                   Views              \
#                                                   count        mean
# Artist   Album
# $NOT     - TRAGEDY +                                3.0   9158825.0
#          Beautiful Havoc                            2.0  14683693.5
#          EAT YOUR HEART OUT                         1.0    681136.0
#          Ethereal                                   1.0  10114989.0
#          Fast & Furious: Drift Tape (Phonk Vol 1)   1.0     76559.0
# ...                                                 ...         ...
# Øneheart snowfall (Slowed + Reverb)                 1.0  15361992.0
#          snowfall (Sped Up)                         1.0   1707355.0
#          this feeling                               1.0    856049.0
#          watching the stars                         1.0    323775.0
#          watching the stars (Remixes)               1.0    139020.0
#
# ...

# %%
df_art_album.describe().loc[["The Beatles", "Pink Floyd"]]
# Out:
#                                           Views                              \
#                                           count          mean           std
# Artist      Album
# The Beatles 1 (Remastered)                  2.0  4.284411e+07  1.986215e+07
#             Abbey Road (Remastered)         3.0  8.114310e+07  4.384534e+07
#             Help! (Remastered)              1.0  4.285668e+07           NaN
#             Let It Be (Remastered)          1.0  1.319251e+08           NaN
#             Please Please Me (Remastered)   1.0  5.322836e+07           NaN
#             Rubber Soul (Remastered)        1.0  6.322312e+07           NaN
#             The Beatles (Remastered)        1.0  3.385295e+07           NaN
# Pink Floyd  The Dark Side of the Moon       6.0  6.011355e+06  1.109252e+07
#             The Wall                        3.0  1.634434e+07  2.262575e+07
#             Wish You Were Here              1.0  3.284820e+05           NaN
#
# ...
