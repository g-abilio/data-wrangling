# %% [markdown]
# # Discretization

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Spotify_Youtube_Sample.csv")
df.head()
# Out:
#      Artist                                          Track  \
# 0  Gorillaz                                 Feel Good Inc.
# 1  Gorillaz                                Rhinestone Eyes
# 2  Gorillaz  New Gold (feat. Tame Impala and Bootie Brown)
# 3  Gorillaz                             On Melancholy Hill
# 4  Gorillaz                                 Clint Eastwood
#
#                                            Album Album_type        Views  \
# 0                                     Demon Days      album  693555221.0
# 1                                  Plastic Beach      album   72011645.0
# 2  New Gold (feat. Tame Impala and Bootie Brown)     single    8435055.0
# 3                                  Plastic Beach      album  211754952.0
# 4                                       Gorillaz      album  618480958.0
#
#        Likes  Comments Licensed official_video        Stream
# 0  6220896.0  169907.0     True           True  1.040235e+09
# 1  1079128.0   31003.0     True           True  3.100837e+08
# 2   282142.0    7399.0     True           True  6.306347e+07
# 3  1788577.0   55229.0     True           True  4.346636e+08
# 4  6197318.0  155930.0     True           True  6.172597e+08

# %%
df.describe()
# Out:
#               Views         Likes      Comments        Stream
# count  2.024800e+04  2.017700e+04  2.014900e+04  2.014200e+04
# mean   9.393782e+07  6.633411e+05  2.751899e+04  1.359422e+08
# std    2.746443e+08  1.789324e+06  1.932347e+05  2.441321e+08
# min    0.000000e+00  0.000000e+00  0.000000e+00  6.574000e+03
# 25%    1.826002e+06  2.158100e+04  5.090000e+02  1.767486e+07
# 50%    1.450110e+07  1.244810e+05  3.277000e+03  4.968298e+07
# 75%    7.039975e+07  5.221480e+05  1.436000e+04  1.383581e+08
# max    8.079649e+09  5.078865e+07  1.608314e+07  3.386520e+09

# %% [markdown]
# ## Discretizing views

# %%
df["Views"].describe()
# Out:
# count    2.024800e+04
# mean     9.393782e+07
# std      2.746443e+08
# min      0.000000e+00
# 25%      1.826002e+06
# 50%      1.450110e+07
# 75%      7.039975e+07
# max      8.079649e+09
# Name: Views, dtype: float64

# %%
condition = [df["Views"] < df["Views"].quantile(0.5), df["Views"] >= df["Views"].quantile(0.5)]
result = ["low", "high"]

# %%
df["Views_state"] = np.select(condition, result)

# %%
df["Views_state"]
# Out:
# 0        high
# 1        high
# 2         low
# 3        high
# 4        high
#          ...
# 20713     low
# 20714     low
# 20715     low
# 20716     low
# 20717     low
# Name: Views_state, Length: 20718, dtype: object

# %%
df["Views_state"].value_counts()
# Out:
# Views_state
# high    10125
# low     10123
# 0         470
# Name: count, dtype: int64

# %% [markdown]
# Probably, zeros are from rows with NaN:

# %%
df.dropna(inplace = True)

# %%
df["Views_state"].value_counts()
# Out:
# Views_state
# high    9852
# low     9698
# Name: count, dtype: int64

# %% [markdown]
# ## Discretizing Comments and Likes

# %% [markdown]
# We can have four attributes:
# 1. Highly commented
# 2. Highly liked
# 3. Weakly commented
# 4. Weakly liked

# %%
condition = [
    ((df["Likes"] >= df["Likes"].quantile(0.5)) & (df["Comments"] >= df["Comments"].quantile(0.5))),
    ((df["Likes"] < df["Likes"].quantile(0.5)) & (df["Comments"] < df["Comments"].quantile(0.5))),
    ((df["Likes"] >= df["Likes"].quantile(0.5)) & (df["Comments"] < df["Comments"].quantile(0.5))),
    ((df["Likes"] < df["Likes"].quantile(0.5)) & (df["Comments"] >= df["Comments"].quantile(0.5)))
]

# %%
result = ["high and high", "low and low", "high and low", "low and high"]

# %%
df["comments_likes"] = np.select(condition, result)

# %%
df["comments_likes"]
# Out:
# 0        high and high
# 1        high and high
# 2        high and high
# 3        high and high
# 4        high and high
#              ...
# 20713      low and low
# 20714      low and low
# 20715      low and low
# 20716      low and low
# 20717      low and low
# Name: comments_likes, Length: 19550, dtype: object

# %%
df["comments_likes"].value_counts()
# Out:
# comments_likes
# high and high    8933
# low and low      8933
# high and low      842
# low and high      842
# Name: count, dtype: int64

# %% [markdown]
# ## Discretizing Stream

# %%
df["Stream"].describe()
# Out:
# count    1.955000e+04
# mean     1.371088e+08
# std      2.463527e+08
# min      6.574000e+03
# 25%      1.781149e+07
# 50%      4.979139e+07
# 75%      1.390790e+08
# max      3.386520e+09
# Name: Stream, dtype: float64

# %%
def discretizing_stream(value):
    if value < df["Stream"].quantile(0.25):
        return "low"
    elif value > df["Stream"].quantile(0.75):
        return "high"
    else:
        return "medium"

# %%
df["stream_state"] = df["Stream"].apply(discretizing_stream)

# %%
df["stream_state"]
# Out:
# 0          high
# 1          high
# 2        medium
# 3          high
# 4          high
#           ...
# 20713       low
# 20714       low
# 20715       low
# 20716       low
# 20717       low
# Name: stream_state, Length: 19550, dtype: object

# %%
df["stream_state"].value_counts()
# Out:
# stream_state
# medium    9774
# high      4888
# low       4888
# Name: count, dtype: int64

# %% [markdown]
# ## Saving the data

# %%
df
# Out:
#             Artist                                          Track  \
# 0         Gorillaz                                 Feel Good Inc.
# 1         Gorillaz                                Rhinestone Eyes
# 2         Gorillaz  New Gold (feat. Tame Impala and Bootie Brown)
# 3         Gorillaz                             On Melancholy Hill
# 4         Gorillaz                                 Clint Eastwood
# ...            ...                                            ...
# 20713  SICK LEGEND                           JUST DANCE HARDSTYLE
# 20714  SICK LEGEND                 SET FIRE TO THE RAIN HARDSTYLE
# 20715  SICK LEGEND                      OUTSIDE HARDSTYLE SPED UP
# 20716  SICK LEGEND                            ONLY GIRL HARDSTYLE
# 20717  SICK LEGEND                             MISS YOU HARDSTYLE
#
#                                                Album Album_type        Views  \
# 0                                         Demon Days      album  693555221.0
# 1                                      Plastic Beach      album   72011645.0
# 2      New Gold (feat. Tame Impala and Bootie Brown)     single    8435055.0
# 3                                      Plastic Beach      album  211754952.0
# 4                                           Gorillaz      album  618480958.0
# ...                                              ...        ...          ...
# 20713                           JUST DANCE HARDSTYLE     single      71678.0
# 20714                 SET FIRE TO THE RAIN HARDSTYLE     single     164741.0
# 20715                      OUTSIDE HARDSTYLE SPED UP     single      35646.0
# 20716                            ONLY GIRL HARDSTYLE     single       6533.0
# 20717                             MISS YOU HARDSTYLE     single     158697.0
#
#            Likes  Comments Licensed official_video        Stream Views_state  \
# 0      6220896.0  169907.0     True           True  1.040235e+09        high
# 1      1079128.0   31003.0     True           True  3.100837e+08        high
# 2       282142.0    7399.0     True           True  6.306347e+07         low
# 3      1788577.0   55229.0     True           True  4.346636e+08        high
# 4      6197318.0  155930.0     True           True  6.172597e+08        high
# ...          ...       ...      ...            ...           ...         ...
# 20713     1113.0       0.0     True           True  9.227144e+06         low
# 20714     2019.0       0.0     True           True  1.089818e+07         low
# 20715      329.0       0.0     True           True  6.226110e+06         low
# 20716       88.0       0.0     True           True  6.873961e+06         low
# 20717     2484.0       0.0     True           True  5.695584e+06         low
#
#       comments_likes stream_state
# 0      high and high         high
# 1      high and high         high
# 2      high and high       medium
# 3      high and high         high
# 4      high and high         high
# ...              ...          ...
# 20713    low and low          low
# 20714    low and low          low
# 20715    low and low          low
# 20716    low and low          low
# 20717    low and low          low
#
# [19550 rows x 13 columns]

# %%
df.to_csv("Spotify_Youtube_new.csv", index = False)

# %%
df_new = pd.read_csv("Spotify_Youtube_new.csv")

# %%
df_new
# Out:
#             Artist                                          Track  \
# 0         Gorillaz                                 Feel Good Inc.
# 1         Gorillaz                                Rhinestone Eyes
# 2         Gorillaz  New Gold (feat. Tame Impala and Bootie Brown)
# 3         Gorillaz                             On Melancholy Hill
# 4         Gorillaz                                 Clint Eastwood
# ...            ...                                            ...
# 19545  SICK LEGEND                           JUST DANCE HARDSTYLE
# 19546  SICK LEGEND                 SET FIRE TO THE RAIN HARDSTYLE
# 19547  SICK LEGEND                      OUTSIDE HARDSTYLE SPED UP
# 19548  SICK LEGEND                            ONLY GIRL HARDSTYLE
# 19549  SICK LEGEND                             MISS YOU HARDSTYLE
#
#                                                Album Album_type        Views  \
# 0                                         Demon Days      album  693555221.0
# 1                                      Plastic Beach      album   72011645.0
# 2      New Gold (feat. Tame Impala and Bootie Brown)     single    8435055.0
# 3                                      Plastic Beach      album  211754952.0
# 4                                           Gorillaz      album  618480958.0
# ...                                              ...        ...          ...
# 19545                           JUST DANCE HARDSTYLE     single      71678.0
# 19546                 SET FIRE TO THE RAIN HARDSTYLE     single     164741.0
# 19547                      OUTSIDE HARDSTYLE SPED UP     single      35646.0
# 19548                            ONLY GIRL HARDSTYLE     single       6533.0
# 19549                             MISS YOU HARDSTYLE     single     158697.0
#
#            Likes  Comments  Licensed  official_video        Stream  \
# 0      6220896.0  169907.0      True            True  1.040235e+09
# 1      1079128.0   31003.0      True            True  3.100837e+08
# 2       282142.0    7399.0      True            True  6.306347e+07
# 3      1788577.0   55229.0      True            True  4.346636e+08
# 4      6197318.0  155930.0      True            True  6.172597e+08
# ...          ...       ...       ...             ...           ...
# 19545     1113.0       0.0      True            True  9.227144e+06
# 19546     2019.0       0.0      True            True  1.089818e+07
# 19547      329.0       0.0      True            True  6.226110e+06
# 19548       88.0       0.0      True            True  6.873961e+06
# 19549     2484.0       0.0      True            True  5.695584e+06
#
#       Views_state comments_likes stream_state
# 0            high  high and high         high
# 1            high  high and high         high
# 2             low  high and high       medium
# 3            high  high and high         high
# 4            high  high and high         high
# ...           ...            ...          ...
# 19545         low    low and low          low
# 19546         low    low and low          low
# 19547         low    low and low          low
# 19548         low    low and low          low
# 19549         low    low and low          low
#
# [19550 rows x 13 columns]
