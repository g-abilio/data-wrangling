# %% [markdown]
# # Pivot Table

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Spotify_Youtube_Sample.csv")
df
# Out:
#             Artist                                          Track  \
# 0         Gorillaz                                 Feel Good Inc.
# 1         Gorillaz                                Rhinestone Eyes
# 2         Gorillaz  New Gold (feat. Tame Impala and Bootie Brown)
# 3         Gorillaz                             On Melancholy Hill
# 4         Gorillaz                                 Clint Eastwood
# ...            ...                                            ...
# 20713  SICK LEGEND                           JUST DANCE HARDSTYLE
# 20714  SICK LEGEND                 SET FIRE TO THE RAIN HARDSTYLE
# 20715  SICK LEGEND                      OUTSIDE HARDSTYLE SPED UP
# 20716  SICK LEGEND                            ONLY GIRL HARDSTYLE
# 20717  SICK LEGEND                             MISS YOU HARDSTYLE
#
#                                                Album Album_type        Views  \
# 0                                         Demon Days      album  693555221.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20718 entries, 0 to 20717
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Artist          20718 non-null  object
#  1   Track           20718 non-null  object
#  2   Album           20718 non-null  object
#  3   Album_type      20718 non-null  object
#  4   Views           20248 non-null  float64
#  5   Likes           20177 non-null  float64
#  6   Comments        20149 non-null  float64
#  7   Licensed        20248 non-null  object
#  8   official_video  20248 non-null  object
#  9   Stream          20142 non-null  float64
# dtypes: float64(4), object(6)
# memory usage: 1.6+ MB

# %% [markdown]
# Pivot table:

# %%
df_pivot = df.pivot_table(values = ["Stream", "Licensed", "official_video"], index = ["Artist", "Album_type"], aggfunc = "sum")
df_pivot
# Out:
#                        Licensed        Stream official_video
# Artist      Album_type
# $NOT        album             6  7.721559e+08              7
#             single            1  3.554821e+08              1
# $uicideboy$ album             5  1.398121e+09              5
#             single            1  7.286275e+08              1
# (G)I-DLE    album             2  2.134717e+08              2
# ...                         ...           ...            ...
# Ñejo        single            7  4.922610e+08              8
# Ñengo Flow  album             3  1.063268e+09              3
#             single            2  4.340464e+08              3
# Øneheart    album          True  4.849015e+06           True
#             single            8  2.503504e+08              9
#
# [3795 rows x 3 columns]

# %% [markdown]
# Playing with the pivot table:

# %%
df_pivot.loc["Pink Floyd"]
# Out:
#            Licensed       Stream official_video
# Album_type
# album             4  557368632.0              4

# %%
df_pivot.loc[["Pink Floyd", "The Beatles"]]
# Out:
#                        Licensed        Stream official_video
# Artist      Album_type
# Pink Floyd  album             4  5.573686e+08              4
# The Beatles album            10  4.509275e+09             10

# %% [markdown]
# Sorting the values:

# %%
df_pivot.sort_values(by = "Stream", ascending = False)
# Out:
#                             Licensed        Stream official_video
# Artist          Album_type
# Post Malone     album              8  1.525126e+10              9
# Ed Sheeran      album              9  1.430238e+10              9
# The Weeknd      album              7  1.303197e+10              8
# XXXTENTACION    album              3  1.205166e+10              5
# Imagine Dragons album             10  1.185831e+10             10
# ...                              ...           ...            ...
# FIFA Sound      single             7  0.000000e+00              7
# New Order       compilation        2  0.000000e+00              2
# Outlawz         compilation    False  0.000000e+00          False
# Jung Kook       single             5  0.000000e+00              6
# Miggy Dela Rosa single             3  0.000000e+00              7
#
# [3795 rows x 3 columns]

# %%
df_pivot.sort_values(by = ["Artist","Stream"], ascending = False)
# Out:
#                        Licensed        Stream official_video
# Artist      Album_type
# Øneheart    single            8  2.503504e+08              9
#             album          True  4.849015e+06           True
# Ñengo Flow  album             3  1.063268e+09              3
#             single            2  4.340464e+08              3
# Ñejo        single            7  4.922610e+08              8
# ...                         ...           ...            ...
# (G)I-DLE    album             2  2.134717e+08              2
# $uicideboy$ album             5  1.398121e+09              5
#             single            1  7.286275e+08              1
# $NOT        album             6  7.721559e+08              7
#             single            1  3.554821e+08              1
#
# [3795 rows x 3 columns]

# %%
df_pivot.sort_values(by = ["Artist","Stream"], ascending = False).loc["Metallica"]
# Out:
#            Licensed       Stream official_video
# Album_type
# album             5  327681785.0              5
# single            2   23966814.0              2

# %%
df_pivot.sort_values(by = ["Artist","Stream"], ascending = False).loc[["Metallica", "Caetano Veloso"]]
# Out:
#                            Licensed       Stream official_video
# Artist         Album_type
# Metallica      album              5  327681785.0              5
#                single             2   23966814.0              2
# Caetano Veloso album              7  164913345.0              8
#                compilation    False   42852463.0           True
